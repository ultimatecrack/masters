# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('EDA_census.csv')
df.head()
# Out:
#     Name  State  Distt. Area Name Area Type Age-group  Total Persons  \
# 0  C2308      0       0     INDIA     Total  All ages     1210854977
# 1  C2308      0       0     INDIA     Total       0-6      164515253
# 2  C2308      0       0     INDIA     Total         7       24826640
# 3  C2308      0       0     INDIA     Total         8       26968373
# 4  C2308      0       0     INDIA     Total         9       23424638
#
#    Total Males  Total Females  Illiterate Persons  ...  TD Persons  TD Males  \
# 0    623270258      587584719           447216165  ...     7238719   5354161
# 1     85752254       78762999           164515253  ...           0         0
# 2     12903364       11923276             6748214  ...           0         0
# 3     14061937       12906436             4131414  ...           0         0
# 4     12214985       11209653             2491904  ...           0         0
#
#    TD Females  G Persons   G Males  G Females  U Persons  U Males  U Females  \
# ...

# %%
df[df['Age-group'] == '20-24']['Illiterate Females'].sum()/df[df['Age-group'] == '20-24']['Total Females'].sum()
# df[''
# Out:
# 0.22683084764727418

# %%
df['Literacy Percentage'] = df['Literate Persons']/df['Total Persons']

# %%
plt.figure(figsize=(23, 5))
sns.barplot(data=df, x='Age-group', y='Literacy Percentage')
# Out:
# <AxesSubplot:xlabel='Age-group', ylabel='Literacy Percentage'>

# %%
df['Female Literacy Percentage'] = df['Literate Females']/df['Total Females']

# %%
plt.figure(figsize=(10, 10))
sns.barplot(data=df, y='Area Name', x='Female Literacy Percentage')
# Out:
# <AxesSubplot:xlabel='Female Literacy Percentage', ylabel='Area Name'>

# %%
plt.figure(figsize=(10, 10))
sns.barplot(data=df, y='Area Name', x='Literacy Percentage')
# Out:
# <AxesSubplot:xlabel='Literacy Percentage', ylabel='Area Name'>

# %%
areawise_literate_persons = pd.DataFrame(df.groupby('Area Name')['Literate Persons'].sum()).reset_index()

# %%
areawise_total_persons = pd.DataFrame(df.groupby('Area Name')['Total Persons'].sum()).reset_index()

# %%
summary = areawise_total_persons.merge(areawise_literate_persons, on='Area Name')

# %%
summary['Literacy Percentage'] = summary['Literate Persons']/summary['Total Persons']

# %%
summary.sort_values('Literacy Percentage')
# Out:
#                             Area Name  Total Persons  Literate Persons  \
# 5                       State - BIHAR      416397808         210018212
# 3           State - ARUNACHAL PRADESH        5534908           3064020
# 15                  State - JHARKHAND      131952536          73312276
# 29                  State - RAJASTHAN      274193748         153101128
# 14            State - JAMMU & KASHMIR       50165208          28268932
# 33              State - UTTAR PRADESH      799249364         457590220
# 19             State - MADHYA PRADESH      290507236         171404676
# 2              State - ANDHRA PRADESH      338323108         202227040
# 22                  State - MEGHALAYA       11867556           7140020
# 7                State - CHHATTISGARH      102180792          61519688
# 4                       State - ASSAM      124822304          76711908
# 0                               INDIA     4843419908        3054555248
# ...
