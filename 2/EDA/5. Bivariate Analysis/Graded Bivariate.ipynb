# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('nas.csv')
df.head()
# Out:
#          STUID        State  District Gender       Age  Category  \
# 0  26011001001  Maharashtra         1   Girl  13 years       3.0
# 1  26011001002  Maharashtra         1   Girl  15 years       3.0
# 2  26011001003  Maharashtra         1   Girl  14 years       3.0
# 3  26011001004  Maharashtra         1    Boy  13 years       3.0
# 4  26011001005  Maharashtra         1   Girl  14 years       3.0
#
#    Same.language    Siblings Handicap      Father.edu  ...  \
# 0            2.0   1 sibling       No      Illiterate  ...
# 1            2.0  3 siblings       No             NaN  ...
# 2            2.0  3 siblings       No  Degree & above  ...
# 3            2.0  3 siblings       No       Secondary  ...
# 4            2.0  2 siblings       No         Primary  ...
#
#   Express.science.views     Watch.TV Read.magazine   Read.a.book   Play.games  \
# 0                 Agree    Every day         Never  Once a month  Once a week
# ...

# %%
df.pivot_table(index='Mother.edu', columns='Siblings')
# Out:
#                 Category                                                 \
# Siblings       1 sibling 2 siblings 3 siblings 4+ siblings Single child
# Mother.edu
# Degree & above  3.082353   2.428571   2.909091    2.166667     3.684211
# Illiterate      2.787449   2.732329   2.700599    2.560920     2.560000
# Primary         2.952381   2.757823   2.659847    2.561702     2.623529
# Secondary       3.010891   2.857849   2.786145    2.836820     2.916667
# Sr secondary    2.958974   2.674797   2.446809    2.681818     3.304348
#
#                 District                                                 ...  \
# Siblings       1 sibling 2 siblings 3 siblings 4+ siblings Single child  ...
# Mother.edu                                                               ...
# Degree & above  8.693182   7.555556   8.000000    7.666667    10.300000  ...
# Illiterate      8.399625   8.523294   7.404135    7.880597     7.477273  ...
# ...

# %%
df[df['Mother.edu'] == 'Illiterate']['Siblings'].mode()
# Out:
# 0    2 siblings
# Name: Siblings, dtype: object

# %%
df.columns.sort_values()
# Out:
# Index(['Age', 'Answer.English.WB', 'Answer.English.aloud', 'Below.poverty',
#        'Category', 'Computer.use', 'Conduct.experiments', 'Correct.Lang.HW',
#        'Correct.Math.HW', 'Correct.Scie.HW', 'Correct.SocS.HW',
#        'Dictionary.to.learn', 'Distance', 'District', 'Draw.geometry',
#        'English.is.difficult', 'Explain.answers', 'Express.SocSci.views',
#        'Express.science.views', 'Father.edu', 'Father.occupation', 'Gender',
#        'Give.Lang.HW', 'Give.Math.HW', 'Give.Scie.HW', 'Give.SoSc.HW',
#        'Handicap', 'Help.in.Study', 'Help.in.household',
#        'Historical.excursions', 'Library.use', 'Like.school', 'Maths..',
#        'Maths.is.difficult', 'Mother.edu', 'Mother.occupation',
#        'Observe.experiments', 'Participate.in.SocSci', 'Play.games',
#        'Private.tuition', 'Read.English', 'Read.a.book', 'Read.magazine',
#        'Read.other.books', 'Reading..', 'STUID', 'Same.language', 'Science..',
# ...

# %%
sns.heatmap(df.pivot_table(index='Father.edu', columns='Age', values='Science..'), annot=True, cmap='YlGn')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Father.edu'>
